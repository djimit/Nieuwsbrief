# %% [markdown]
# <a href="https://colab.research.google.com/github/djimit/Nieuwsbrief/blob/main/Nieuwsbrief.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
from newspaper import Article
from datetime import datetime
import pandas as pd
import time
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from urllib.parse import urljoin, urlparse

# Download NLTK data
nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)

def is_valid_url(url):
    parsed = urlparse(url)
    return bool(parsed.netloc) and bool(parsed.scheme)

def is_ai_related(text):
    ai_keywords = [
        'artificial intelligence', 'machine learning', 'deep learning', 'neural network',
        'AI', 'ML', 'NLP', 'computer vision', 'robotics', 'autonomous', 'algorithm',
        'kunstmatige intelligentie', 'KI', 'machinaal leren', 'diep leren', 'neurale netwerken',
        'big data', 'data science', 'predictive analytics', 'natural language processing',
        'reinforcement learning', 'computer vision', 'expert system', 'cognitive computing',
        'machine perception', 'AI ethics', 'AI policy', 'AI regulation', 'AI governance',
        'AI research', 'AI development', 'AI innovation', 'AI technology', 'AI application'
    ]

    stop_words = set(stopwords.words('english') + stopwords.words('dutch'))
    word_tokens = word_tokenize(text.lower())
    filtered_text = [w for w in word_tokens if not w in stop_words]

    for i in range(len(filtered_text) - 1):
        if f"{filtered_text[i]} {filtered_text[i+1]}" in ai_keywords:
            return True
    return any(keyword.lower() in filtered_text for keyword in ai_keywords)

def is_irrelevant(text):
    irrelevant_keywords = ['airpods', 'iphone', 'smartphone', 'gadget']
    return any(keyword.lower() in text.lower() for keyword in irrelevant_keywords)

def scrape_article(url):
    try:
        article = Article(url)
        article.download()
        article.parse()
        article.nlp()

        if is_ai_related(article.title + " " + article.text) and not is_irrelevant(article.title + " " + article.text):
            return {
                'title': article.title,
                'url': url,
                'summary': article.summary,
                'keywords': ', '.join(article.keywords),
                'published_date': article.publish_date or datetime.now(),
                'source': article.source_url
            }
    except Exception as e:
        print(f"Error scraping article {url}: {str(e)}")
    return None

def scrape_news_site(base_url, ai_section_url=None):
    articles = []
    try:
        url_to_scrape = ai_section_url if ai_section_url else base_url
        response = requests.get(url_to_scrape, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        for link in soup.find_all('a', href=True):
            url = urljoin(base_url, link['href'])

            if not is_valid_url(url):
                continue

            if re.search(r'/\d{4}/\d{2}/\d{2}/', url) or '/article/' in url or '/news/' in url:
                article = scrape_article(url)
                if article:
                    articles.append(article)
                    print(f"Scraped: {article['title']}")
                time.sleep(1)

            if len(articles) >= 5:
                break

    except requests.RequestException as e:
        print(f"Error fetching {url_to_scrape}: {str(e)}")
    except Exception as e:
        print(f"Unexpected error scraping {base_url}: {str(e)}")

    return articles

# Lijst van websites om te scrapen
websites = [
    # Europese Commissie en gerelateerde bronnen
    {'name': 'European Commission - AI', 'url': 'https://digital-strategy.ec.europa.eu/en/policies/artificial-intelligence'},
    {'name': 'EU Science Hub - AI', 'url': 'https://ec.europa.eu/jrc/en/research-topic/artificial-intelligence'},

    # Amerikaanse overheid
    {'name': 'White House - AI', 'url': 'https://www.whitehouse.gov/ai/'},
    {'name': 'National Artificial Intelligence Initiative', 'url': 'https://www.ai.gov/'},

    # Silicon Valley en Tech bedrijven
    {'name': 'Google AI', 'url': 'https://ai.google/'},
    {'name': 'Microsoft AI Blog', 'url': 'https://blogs.microsoft.com/ai/'},
    {'name': 'OpenAI Blog', 'url': 'https://openai.com/blog/'},
    {'name': 'DeepMind Blog', 'url': 'https://deepmind.com/blog'},
    {'name': 'IBM AI Research', 'url': 'https://www.ibm.com/artificial-intelligence'},

    # Onderzoeksinstituten en universiteiten
    {'name': 'MIT AI', 'url': 'https://www.csail.mit.edu/research/artificial-intelligence'},
    {'name': 'Stanford AI Lab', 'url': 'https://ai.stanford.edu/'},
    {'name': 'Berkeley AI Research', 'url': 'https://bair.berkeley.edu/blog/'},
    {'name': 'Harvard AI', 'url': 'https://ai.harvard.edu/'},

    # AI-specifieke nieuwssites
    {'name': 'AI News', 'url': 'https://artificialintelligence-news.com/'},
    {'name': 'Machine Learning Mastery', 'url': 'https://machinelearningmastery.com/blog/'},
    {'name': 'KDnuggets', 'url': 'https://www.kdnuggets.com/'},
    {'name': 'Analytics Vidhya', 'url': 'https://www.analyticsvidhya.com/blog/'},

    # Algemene tech-nieuwssites met AI-secties
    {'name': 'TechCrunch', 'url': 'https://techcrunch.com', 'ai_section': 'https://techcrunch.com/category/artificial-intelligence/'},
    {'name': 'VentureBeat', 'url': 'https://venturebeat.com', 'ai_section': 'https://venturebeat.com/category/ai/'},
    {'name': 'MIT Technology Review', 'url': 'https://www.technologyreview.com', 'ai_section': 'https://www.technologyreview.com/topic/artificial-intelligence/'},
    {'name': 'Wired', 'url': 'https://www.wired.com', 'ai_section': 'https://www.wired.com/tag/artificial-intelligence/'},
    {'name': 'Forbes AI', 'url': 'https://www.forbes.com/ai'},

    # Nederlandse bronnen
    {'name': 'Nederlandse AI Coalitie', 'url': 'https://nlaic.com/en/news/'},
    {'name': 'TNO - AI', 'url': 'https://www.tno.nl/en/focus-areas/information-communication-technology/roadmaps/data-sharing/artificial-intelligence/'},
    {'name': 'AI Krant', 'url': 'https://www.ai-krant.nl/'},

    # Internationale organisaties
    {'name': 'OECD AI Policy Observatory', 'url': 'https://oecd.ai/'},
    {'name': 'UNESCO Artificial Intelligence', 'url': 'https://en.unesco.org/artificial-intelligence'},

    # AI Ethics en Policy
    {'name': 'AI Ethics Lab', 'url': 'https://aiethicslab.com/'},
    {'name': 'Future of Life Institute', 'url': 'https://futureoflife.org/ai-news/'},
]

def add_website(name, url, ai_section=None):
    """
    Voegt een nieuwe website toe aan de lijst om te scrapen.

    :param name: Naam van de website
    :param url: Basis-URL van de website
    :param ai_section: Optionele URL voor de AI-specifieke sectie van de website
    """
    new_site = {'name': name, 'url': url}
    if ai_section:
        new_site['ai_section'] = ai_section
    websites.append(new_site)
    print(f"Toegevoegd: {name}")

def scrape_multiple_sites():
    all_articles = []
    for site in websites:
        print(f"Scraping {site['name']}...")
        articles = scrape_news_site(site['url'], site.get('ai_section'))
        all_articles.extend(articles)

    return pd.DataFrame(all_articles)

# Voorbeeld van het toevoegen van een nieuwe website
add_website("AI Trends", "https://www.aitrends.com/")

# Run de scraper
news_df = scrape_multiple_sites()

# Toon de resultaten
display(news_df[['title', 'url', 'summary', 'keywords', 'published_date', 'source']])
# Out:
# Toegevoegd: AI Trends
# Scraping European Commission - AI...
# Scraped: Artificial Intelligence Board kicks off work on uptake of AI in the EU and implementation of the AI Act
# Scraped: EU boosts European AI developers with the AI Factories call for proposals
# Scraped: AI Office received strong interest for participation in drafting the first General-Purpose AI Code of Practice
# Scraping EU Science Hub - AI...
# Error fetching https://ec.europa.eu/jrc/en/research-topic/artificial-intelligence: 404 Client Error: Not Found for url: https://joint-research-centre.ec.europa.eu/scientific-activities/artificial-intelligence_en
# Scraping White House - AI...
# Error fetching https://www.whitehouse.gov/ai/: 404 Client Error: Not Found for url: https://www.whitehouse.gov/ai/
# Scraping National Artificial Intelligence Initiative...
# Scraping Google AI...
# Scraped: Using AI to help more college students graduate
# Scraping Microsoft AI Blog...
# Error fetching https://blogs.microsoft.com/ai/: 403 Client Error: Forbidden for url: https://news.microsoft.com/source/topics/ai/
# Scraping OpenAI Blog...
# Error fetching https://openai.com/blog/: 403 Client Error: Forbidden for url: https://openai.com/blog/
# Scraping DeepMind Blog...
# Scraping IBM AI Research...
# Scraping MIT AI...
# Error fetching https://www.csail.mit.edu/research/artificial-intelligence: 404 Client Error: Not Found for url: https://www.csail.mit.edu/research/artificial-intelligence
# Scraping Stanford AI Lab...
# Scraped: Announcing the NeurIPS 2023 Paper Awards – NeurIPS Blog
# Scraping Berkeley AI Research...
# Scraped: How to Evaluate Jailbreak Methods: A Case Study with the StrongREJECT Benchmark
# Scraped: How to Evaluate Jailbreak Methods: A Case Study with the StrongREJECT Benchmark
# Scraped: Are We Ready for Multi-Image Reasoning? Launching VHs: The Visual Haystacks Benchmark!
# Scraped: Are We Ready for Multi-Image Reasoning? Launching VHs: The Visual Haystacks Benchmark!
# Scraped: TinyAgent: Function Calling at the Edge
# Scraping Harvard AI...
# Scraped: Exploring Ways AI Can Address Oral Health Disparities
# Scraping AI News...
# Scraped: AI winter: A cycle of hype, disappointment, and recovery
# Scraped: AI winter: A cycle of hype, disappointment, and recovery
# Scraped: AI winter: A cycle of hype, disappointment, and recovery
# Scraped: OpenAI co-founder’s Safe Superintelligence Inc secures $1B
# Scraped: OpenAI co-founder’s Safe Superintelligence Inc secures $1B
# Scraping Machine Learning Mastery...
# Error fetching https://machinelearningmastery.com/blog/: 403 Client Error: Forbidden for url: https://machinelearningmastery.com/blog/
# Scraping KDnuggets...
# Error fetching https://www.kdnuggets.com/: 403 Client Error: Forbidden for url: https://www.kdnuggets.com/
# Scraping Analytics Vidhya...
# Scraping TechCrunch...
# Scraped: Smartcat secures $43M for its AI-powered translation platform
# Scraped: Smartcat secures $43M for its AI-powered translation platform
# Scraped: Heart disease is the world’s biggest killer — this Cambridge Uni spinout is using AI to find new treatments
# Scraped: Heart disease is the world’s biggest killer — this Cambridge Uni spinout is using AI to find new treatments
# Scraped: Apple upgrades watchOS with AI-powered features, including translation
# Scraping VentureBeat...
# Scraping MIT Technology Review...
# Scraping Wired...
# Scraping Forbes AI...
# Error scraping article https://www.forbes.com/sites/alexknapp/2024/09/10/this-startup-aims-to-regenerate-damaged-tissues-with-the-help-of-ai-and-lasers/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/alexknapp/2024/09/10/this-startup-aims-to-regenerate-damaged-tissues-with-the-help-of-ai-and-lasers/?ss=ai on URL https://www.forbes.com/sites/alexknapp/2024/09/10/this-startup-aims-to-regenerate-damaged-tissues-with-the-help-of-ai-and-lasers/?ss=ai
# Error scraping article https://www.forbes.com/sites/rashishrivastava/2024/09/03/the-prompt-stable-diffusion-enabled-ruthless-exploitation-of-children-cops-say/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/rashishrivastava/2024/09/03/the-prompt-stable-diffusion-enabled-ruthless-exploitation-of-children-cops-say/?ss=ai on URL https://www.forbes.com/sites/rashishrivastava/2024/09/03/the-prompt-stable-diffusion-enabled-ruthless-exploitation-of-children-cops-say/?ss=ai
# Error scraping article https://www.forbes.com/sites/alanohnsman/2024/09/02/tech-firms-keep-users-in-the-dark-on-ais-climate-costs-tesla-manifesto-hybrid-trucks/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/alanohnsman/2024/09/02/tech-firms-keep-users-in-the-dark-on-ais-climate-costs-tesla-manifesto-hybrid-trucks/?ss=ai on URL https://www.forbes.com/sites/alanohnsman/2024/09/02/tech-firms-keep-users-in-the-dark-on-ais-climate-costs-tesla-manifesto-hybrid-trucks/?ss=ai
# Error scraping article https://www.forbes.com/sites/ericsiegel/2024/09/01/california-wants-to-regulate-ai-but-cant-even-define-it/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/ericsiegel/2024/09/01/california-wants-to-regulate-ai-but-cant-even-define-it/?ss=ai on URL https://www.forbes.com/sites/ericsiegel/2024/09/01/california-wants-to-regulate-ai-but-cant-even-define-it/?ss=ai
# Error scraping article https://www.forbes.com/sites/rashishrivastava/2024/08/27/the-prompt-north-korean-operatives-are-using-ai-to-get-remote-it-jobs/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/rashishrivastava/2024/08/27/the-prompt-north-korean-operatives-are-using-ai-to-get-remote-it-jobs/?ss=ai on URL https://www.forbes.com/sites/rashishrivastava/2024/08/27/the-prompt-north-korean-operatives-are-using-ai-to-get-remote-it-jobs/?ss=ai
# Error scraping article https://www.forbes.com/sites/alanohnsman/2024/08/26/waymo-adding-a-second-robotaxi-assembly-facility/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/alanohnsman/2024/08/26/waymo-adding-a-second-robotaxi-assembly-facility/?ss=ai on URL https://www.forbes.com/sites/alanohnsman/2024/08/26/waymo-adding-a-second-robotaxi-assembly-facility/?ss=ai
# Error scraping article https://www.forbes.com/sites/alanohnsman/2024/09/02/tech-firms-keep-users-in-the-dark-on-ais-climate-costs-tesla-manifesto-hybrid-trucks/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/alanohnsman/2024/09/02/tech-firms-keep-users-in-the-dark-on-ais-climate-costs-tesla-manifesto-hybrid-trucks/?ss=ai on URL https://www.forbes.com/sites/alanohnsman/2024/09/02/tech-firms-keep-users-in-the-dark-on-ais-climate-costs-tesla-manifesto-hybrid-trucks/?ss=ai
# Error scraping article https://www.forbes.com/sites/alanohnsman/2024/09/02/tech-firms-keep-users-in-the-dark-on-ais-climate-costs-tesla-manifesto-hybrid-trucks/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/alanohnsman/2024/09/02/tech-firms-keep-users-in-the-dark-on-ais-climate-costs-tesla-manifesto-hybrid-trucks/?ss=ai on URL https://www.forbes.com/sites/alanohnsman/2024/09/02/tech-firms-keep-users-in-the-dark-on-ais-climate-costs-tesla-manifesto-hybrid-trucks/?ss=ai
# Error scraping article https://www.forbes.com/sites/tonybradley/2024/08/08/rebalancing-cybersecurity-for-the-future/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/tonybradley/2024/08/08/rebalancing-cybersecurity-for-the-future/?ss=ai on URL https://www.forbes.com/sites/tonybradley/2024/08/08/rebalancing-cybersecurity-for-the-future/?ss=ai
# Error scraping article https://www.forbes.com/sites/tonybradley/2024/08/08/rebalancing-cybersecurity-for-the-future/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/tonybradley/2024/08/08/rebalancing-cybersecurity-for-the-future/?ss=ai on URL https://www.forbes.com/sites/tonybradley/2024/08/08/rebalancing-cybersecurity-for-the-future/?ss=ai
# Error scraping article https://www.forbes.com/sites/rashishrivastava/2024/08/06/how-the-ai-boom-minted-a-new-breed-of-billion-dollar-cloud-companies/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/rashishrivastava/2024/08/06/how-the-ai-boom-minted-a-new-breed-of-billion-dollar-cloud-companies/?ss=ai on URL https://www.forbes.com/sites/rashishrivastava/2024/08/06/how-the-ai-boom-minted-a-new-breed-of-billion-dollar-cloud-companies/?ss=ai
# Error scraping article https://www.forbes.com/sites/rashishrivastava/2024/08/06/how-the-ai-boom-minted-a-new-breed-of-billion-dollar-cloud-companies/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/rashishrivastava/2024/08/06/how-the-ai-boom-minted-a-new-breed-of-billion-dollar-cloud-companies/?ss=ai on URL https://www.forbes.com/sites/rashishrivastava/2024/08/06/how-the-ai-boom-minted-a-new-breed-of-billion-dollar-cloud-companies/?ss=ai
# Error scraping article https://www.forbes.com/sites/janakirammsv/2024/08/08/writer-launches-new-llms-for-healthcare-and-finance-industries/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/janakirammsv/2024/08/08/writer-launches-new-llms-for-healthcare-and-finance-industries/?ss=ai on URL https://www.forbes.com/sites/janakirammsv/2024/08/08/writer-launches-new-llms-for-healthcare-and-finance-industries/?ss=ai
# Error scraping article https://www.forbes.com/sites/janakirammsv/2024/08/08/writer-launches-new-llms-for-healthcare-and-finance-industries/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/janakirammsv/2024/08/08/writer-launches-new-llms-for-healthcare-and-finance-industries/?ss=ai on URL https://www.forbes.com/sites/janakirammsv/2024/08/08/writer-launches-new-llms-for-healthcare-and-finance-industries/?ss=ai
# Error scraping article https://www.forbes.com/sites/davealtavilla/2024/09/10/intel-lunar-lake-processors-are-set-to-shake-up-the-ai-pc-landscape/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/davealtavilla/2024/09/10/intel-lunar-lake-processors-are-set-to-shake-up-the-ai-pc-landscape/?ss=ai on URL https://www.forbes.com/sites/davealtavilla/2024/09/10/intel-lunar-lake-processors-are-set-to-shake-up-the-ai-pc-landscape/?ss=ai
# Error scraping article https://www.forbes.com/sites/davealtavilla/2024/09/10/intel-lunar-lake-processors-are-set-to-shake-up-the-ai-pc-landscape/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/davealtavilla/2024/09/10/intel-lunar-lake-processors-are-set-to-shake-up-the-ai-pc-landscape/?ss=ai on URL https://www.forbes.com/sites/davealtavilla/2024/09/10/intel-lunar-lake-processors-are-set-to-shake-up-the-ai-pc-landscape/?ss=ai
# Error scraping article https://www.forbes.com/sites/davidteich/2024/09/10/taming-silicon-valley-a-book-about-whats-needed-for-ai-and-society/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/davidteich/2024/09/10/taming-silicon-valley-a-book-about-whats-needed-for-ai-and-society/?ss=ai on URL https://www.forbes.com/sites/davidteich/2024/09/10/taming-silicon-valley-a-book-about-whats-needed-for-ai-and-society/?ss=ai
# Error scraping article https://www.forbes.com/sites/davidteich/2024/09/10/taming-silicon-valley-a-book-about-whats-needed-for-ai-and-society/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/davidteich/2024/09/10/taming-silicon-valley-a-book-about-whats-needed-for-ai-and-society/?ss=ai on URL https://www.forbes.com/sites/davidteich/2024/09/10/taming-silicon-valley-a-book-about-whats-needed-for-ai-and-society/?ss=ai
# Error scraping article https://www.forbes.com/sites/alexknapp/2024/09/10/this-startup-aims-to-regenerate-damaged-tissues-with-the-help-of-ai-and-lasers/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/alexknapp/2024/09/10/this-startup-aims-to-regenerate-damaged-tissues-with-the-help-of-ai-and-lasers/?ss=ai on URL https://www.forbes.com/sites/alexknapp/2024/09/10/this-startup-aims-to-regenerate-damaged-tissues-with-the-help-of-ai-and-lasers/?ss=ai
# Error scraping article https://www.forbes.com/sites/alexknapp/2024/09/10/this-startup-aims-to-regenerate-damaged-tissues-with-the-help-of-ai-and-lasers/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/alexknapp/2024/09/10/this-startup-aims-to-regenerate-damaged-tissues-with-the-help-of-ai-and-lasers/?ss=ai on URL https://www.forbes.com/sites/alexknapp/2024/09/10/this-startup-aims-to-regenerate-damaged-tissues-with-the-help-of-ai-and-lasers/?ss=ai
# Error scraping article https://www.forbes.com/sites/prakharkhanna/2024/09/10/iphone-16-iphone-16-pro-to-ship-without-this-key-feature-at-launch/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/prakharkhanna/2024/09/10/iphone-16-iphone-16-pro-to-ship-without-this-key-feature-at-launch/?ss=ai on URL https://www.forbes.com/sites/prakharkhanna/2024/09/10/iphone-16-iphone-16-pro-to-ship-without-this-key-feature-at-launch/?ss=ai
# Error scraping article https://www.forbes.com/sites/prakharkhanna/2024/09/10/iphone-16-iphone-16-pro-to-ship-without-this-key-feature-at-launch/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/prakharkhanna/2024/09/10/iphone-16-iphone-16-pro-to-ship-without-this-key-feature-at-launch/?ss=ai on URL https://www.forbes.com/sites/prakharkhanna/2024/09/10/iphone-16-iphone-16-pro-to-ship-without-this-key-feature-at-launch/?ss=ai
# Error scraping article https://www.forbes.com/sites/bernardmarr/2024/09/10/can-your-device-run-apple-intelligence-what-you-need-to-know/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/bernardmarr/2024/09/10/can-your-device-run-apple-intelligence-what-you-need-to-know/?ss=ai on URL https://www.forbes.com/sites/bernardmarr/2024/09/10/can-your-device-run-apple-intelligence-what-you-need-to-know/?ss=ai
# Error scraping article https://www.forbes.com/sites/bernardmarr/2024/09/10/can-your-device-run-apple-intelligence-what-you-need-to-know/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/bernardmarr/2024/09/10/can-your-device-run-apple-intelligence-what-you-need-to-know/?ss=ai on URL https://www.forbes.com/sites/bernardmarr/2024/09/10/can-your-device-run-apple-intelligence-what-you-need-to-know/?ss=ai
# Error scraping article https://www.forbes.com/sites/johnwerner/2024/09/09/what-about-edge-ai/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/johnwerner/2024/09/09/what-about-edge-ai/?ss=ai on URL https://www.forbes.com/sites/johnwerner/2024/09/09/what-about-edge-ai/?ss=ai
# Error scraping article https://www.forbes.com/sites/johnwerner/2024/09/09/what-about-edge-ai/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/johnwerner/2024/09/09/what-about-edge-ai/?ss=ai on URL https://www.forbes.com/sites/johnwerner/2024/09/09/what-about-edge-ai/?ss=ai
# Error scraping article https://www.forbes.com/sites/spencerdorn/2024/09/09/3-ways-to-manage-ai-hype-in-healthcare/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/spencerdorn/2024/09/09/3-ways-to-manage-ai-hype-in-healthcare/?ss=ai on URL https://www.forbes.com/sites/spencerdorn/2024/09/09/3-ways-to-manage-ai-hype-in-healthcare/?ss=ai
# Error scraping article https://www.forbes.com/sites/spencerdorn/2024/09/09/3-ways-to-manage-ai-hype-in-healthcare/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/spencerdorn/2024/09/09/3-ways-to-manage-ai-hype-in-healthcare/?ss=ai on URL https://www.forbes.com/sites/spencerdorn/2024/09/09/3-ways-to-manage-ai-hype-in-healthcare/?ss=ai
# Error scraping article https://www.forbes.com/sites/corneliawalther/2024/09/09/can-we-use-ai-to-feel-less-lonely/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/corneliawalther/2024/09/09/can-we-use-ai-to-feel-less-lonely/?ss=ai on URL https://www.forbes.com/sites/corneliawalther/2024/09/09/can-we-use-ai-to-feel-less-lonely/?ss=ai
# Error scraping article https://www.forbes.com/sites/corneliawalther/2024/09/09/can-we-use-ai-to-feel-less-lonely/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/corneliawalther/2024/09/09/can-we-use-ai-to-feel-less-lonely/?ss=ai on URL https://www.forbes.com/sites/corneliawalther/2024/09/09/can-we-use-ai-to-feel-less-lonely/?ss=ai
# Error scraping article https://www.forbes.com/sites/solrashidi/2024/09/09/luxury-brands-are-fighting-counterfeits-with-ai-and-computer-vision/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/solrashidi/2024/09/09/luxury-brands-are-fighting-counterfeits-with-ai-and-computer-vision/?ss=ai on URL https://www.forbes.com/sites/solrashidi/2024/09/09/luxury-brands-are-fighting-counterfeits-with-ai-and-computer-vision/?ss=ai
# Error scraping article https://www.forbes.com/sites/solrashidi/2024/09/09/luxury-brands-are-fighting-counterfeits-with-ai-and-computer-vision/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/solrashidi/2024/09/09/luxury-brands-are-fighting-counterfeits-with-ai-and-computer-vision/?ss=ai on URL https://www.forbes.com/sites/solrashidi/2024/09/09/luxury-brands-are-fighting-counterfeits-with-ai-and-computer-vision/?ss=ai
# Error scraping article https://www.forbes.com/sites/lanceeliot/2024/09/09/using-generative-ai-to-figure-out-what-people-mean-versus-what-they-say/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/lanceeliot/2024/09/09/using-generative-ai-to-figure-out-what-people-mean-versus-what-they-say/?ss=ai on URL https://www.forbes.com/sites/lanceeliot/2024/09/09/using-generative-ai-to-figure-out-what-people-mean-versus-what-they-say/?ss=ai
# Error scraping article https://www.forbes.com/sites/lanceeliot/2024/09/09/using-generative-ai-to-figure-out-what-people-mean-versus-what-they-say/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/lanceeliot/2024/09/09/using-generative-ai-to-figure-out-what-people-mean-versus-what-they-say/?ss=ai on URL https://www.forbes.com/sites/lanceeliot/2024/09/09/using-generative-ai-to-figure-out-what-people-mean-versus-what-they-say/?ss=ai
# Error scraping article https://www.forbes.com/sites/bernardmarr/2024/09/09/10-amazing-things-you-can-do-with-apple-intelligence-on-your-iphone/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/bernardmarr/2024/09/09/10-amazing-things-you-can-do-with-apple-intelligence-on-your-iphone/?ss=ai on URL https://www.forbes.com/sites/bernardmarr/2024/09/09/10-amazing-things-you-can-do-with-apple-intelligence-on-your-iphone/?ss=ai
# Error scraping article https://www.forbes.com/sites/bernardmarr/2024/09/09/10-amazing-things-you-can-do-with-apple-intelligence-on-your-iphone/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/bernardmarr/2024/09/09/10-amazing-things-you-can-do-with-apple-intelligence-on-your-iphone/?ss=ai on URL https://www.forbes.com/sites/bernardmarr/2024/09/09/10-amazing-things-you-can-do-with-apple-intelligence-on-your-iphone/?ss=ai
# Error scraping article https://www.forbes.com/sites/johnwerner/2024/09/07/ai-art-might-help-us-to-improve-the-job-market/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/johnwerner/2024/09/07/ai-art-might-help-us-to-improve-the-job-market/?ss=ai on URL https://www.forbes.com/sites/johnwerner/2024/09/07/ai-art-might-help-us-to-improve-the-job-market/?ss=ai
# Error scraping article https://www.forbes.com/sites/johnwerner/2024/09/07/ai-art-might-help-us-to-improve-the-job-market/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/johnwerner/2024/09/07/ai-art-might-help-us-to-improve-the-job-market/?ss=ai on URL https://www.forbes.com/sites/johnwerner/2024/09/07/ai-art-might-help-us-to-improve-the-job-market/?ss=ai
# Error scraping article https://www.forbes.com/sites/lanceeliot/2024/09/07/ingenious-self-ask-prompting-technique-boosts-generative-ai/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/lanceeliot/2024/09/07/ingenious-self-ask-prompting-technique-boosts-generative-ai/?ss=ai on URL https://www.forbes.com/sites/lanceeliot/2024/09/07/ingenious-self-ask-prompting-technique-boosts-generative-ai/?ss=ai
# Error scraping article https://www.forbes.com/sites/lanceeliot/2024/09/07/ingenious-self-ask-prompting-technique-boosts-generative-ai/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/lanceeliot/2024/09/07/ingenious-self-ask-prompting-technique-boosts-generative-ai/?ss=ai on URL https://www.forbes.com/sites/lanceeliot/2024/09/07/ingenious-self-ask-prompting-technique-boosts-generative-ai/?ss=ai
# Error scraping article https://www.forbes.com/sites/tonybradley/2024/09/06/the-cybersecurity-cat-and-mouse-game/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/tonybradley/2024/09/06/the-cybersecurity-cat-and-mouse-game/?ss=ai on URL https://www.forbes.com/sites/tonybradley/2024/09/06/the-cybersecurity-cat-and-mouse-game/?ss=ai
# Error scraping article https://www.forbes.com/sites/tonybradley/2024/09/06/the-cybersecurity-cat-and-mouse-game/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/tonybradley/2024/09/06/the-cybersecurity-cat-and-mouse-game/?ss=ai on URL https://www.forbes.com/sites/tonybradley/2024/09/06/the-cybersecurity-cat-and-mouse-game/?ss=ai
# Error scraping article https://www.forbes.com/sites/charliefink/2024/09/06/magic-ai-story-protocol-miris-viggle-catch-cash-apple-intelligence-arrives-with-ios-18/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/charliefink/2024/09/06/magic-ai-story-protocol-miris-viggle-catch-cash-apple-intelligence-arrives-with-ios-18/?ss=ai on URL https://www.forbes.com/sites/charliefink/2024/09/06/magic-ai-story-protocol-miris-viggle-catch-cash-apple-intelligence-arrives-with-ios-18/?ss=ai
# Error scraping article https://www.forbes.com/sites/charliefink/2024/09/06/magic-ai-story-protocol-miris-viggle-catch-cash-apple-intelligence-arrives-with-ios-18/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/charliefink/2024/09/06/magic-ai-story-protocol-miris-viggle-catch-cash-apple-intelligence-arrives-with-ios-18/?ss=ai on URL https://www.forbes.com/sites/charliefink/2024/09/06/magic-ai-story-protocol-miris-viggle-catch-cash-apple-intelligence-arrives-with-ios-18/?ss=ai
# Error scraping article https://www.forbes.com/sites/tonybradley/2024/09/06/torq-gives-back-to-empower-future-cyber-talent/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/tonybradley/2024/09/06/torq-gives-back-to-empower-future-cyber-talent/?ss=ai on URL https://www.forbes.com/sites/tonybradley/2024/09/06/torq-gives-back-to-empower-future-cyber-talent/?ss=ai
# Error scraping article https://www.forbes.com/sites/tonybradley/2024/09/06/torq-gives-back-to-empower-future-cyber-talent/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/tonybradley/2024/09/06/torq-gives-back-to-empower-future-cyber-talent/?ss=ai on URL https://www.forbes.com/sites/tonybradley/2024/09/06/torq-gives-back-to-empower-future-cyber-talent/?ss=ai
# Error scraping article https://www.forbes.com/sites/johnwerner/2024/09/06/skipping-the-line-next-gen-systems-with-transformative-dimensional-ai/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/johnwerner/2024/09/06/skipping-the-line-next-gen-systems-with-transformative-dimensional-ai/?ss=ai on URL https://www.forbes.com/sites/johnwerner/2024/09/06/skipping-the-line-next-gen-systems-with-transformative-dimensional-ai/?ss=ai
# Error scraping article https://www.forbes.com/sites/johnwerner/2024/09/06/skipping-the-line-next-gen-systems-with-transformative-dimensional-ai/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/johnwerner/2024/09/06/skipping-the-line-next-gen-systems-with-transformative-dimensional-ai/?ss=ai on URL https://www.forbes.com/sites/johnwerner/2024/09/06/skipping-the-line-next-gen-systems-with-transformative-dimensional-ai/?ss=ai
# Error scraping article https://www.forbes.com/sites/jodiecook/2024/09/06/9-chatgpt-prompts-to-start-your-own-business/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/jodiecook/2024/09/06/9-chatgpt-prompts-to-start-your-own-business/?ss=ai on URL https://www.forbes.com/sites/jodiecook/2024/09/06/9-chatgpt-prompts-to-start-your-own-business/?ss=ai
# Error scraping article https://www.forbes.com/sites/jodiecook/2024/09/06/9-chatgpt-prompts-to-start-your-own-business/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/jodiecook/2024/09/06/9-chatgpt-prompts-to-start-your-own-business/?ss=ai on URL https://www.forbes.com/sites/jodiecook/2024/09/06/9-chatgpt-prompts-to-start-your-own-business/?ss=ai
# Error scraping article https://www.forbes.com/sites/bernardmarr/2024/09/06/agentic-ai-the-next-big-breakthrough-thats-transforming-business-and-technology/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/bernardmarr/2024/09/06/agentic-ai-the-next-big-breakthrough-thats-transforming-business-and-technology/?ss=ai on URL https://www.forbes.com/sites/bernardmarr/2024/09/06/agentic-ai-the-next-big-breakthrough-thats-transforming-business-and-technology/?ss=ai
# Error scraping article https://www.forbes.com/sites/bernardmarr/2024/09/06/agentic-ai-the-next-big-breakthrough-thats-transforming-business-and-technology/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/bernardmarr/2024/09/06/agentic-ai-the-next-big-breakthrough-thats-transforming-business-and-technology/?ss=ai on URL https://www.forbes.com/sites/bernardmarr/2024/09/06/agentic-ai-the-next-big-breakthrough-thats-transforming-business-and-technology/?ss=ai
# Error scraping article https://www.forbes.com/sites/johnwerner/2024/09/05/robots-may-help-out-on-the-moon-this-time/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/johnwerner/2024/09/05/robots-may-help-out-on-the-moon-this-time/?ss=ai on URL https://www.forbes.com/sites/johnwerner/2024/09/05/robots-may-help-out-on-the-moon-this-time/?ss=ai
# Error scraping article https://www.forbes.com/sites/johnwerner/2024/09/05/robots-may-help-out-on-the-moon-this-time/?ss=ai: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/johnwerner/2024/09/05/robots-may-help-out-on-the-moon-this-time/?ss=ai on URL https://www.forbes.com/sites/johnwerner/2024/09/05/robots-may-help-out-on-the-moon-this-time/?ss=ai
# Scraping Nederlandse AI Coalitie...
# Scraped: News • Nederlandse AI Coalitie
# Scraped: Center of Expertise for healthcare algorithms comes up with scalable AI models. • Nederlandse AI Coalitie
# Scraped: News • Nederlandse AI Coalitie
# Scraped: News • Nederlandse AI Coalitie
# Scraped: News • Nederlandse AI Coalitie
# Scraping TNO - AI...
# Error fetching https://www.tno.nl/en/focus-areas/information-communication-technology/roadmaps/data-sharing/artificial-intelligence/: 403 Client Error: Forbidden for url: https://www.tno.nl/en/focus-areas/information-communication-technology/roadmaps/data-sharing/artificial-intelligence/
# Scraping AI Krant...
# Error fetching https://www.ai-krant.nl/: HTTPSConnectionPool(host='www.ai-krant.nl', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.ai-krant.nl'. (_ssl.c:1007)")))
# Scraping OECD AI Policy Observatory...
# Scraping UNESCO Artificial Intelligence...
# Scraping AI Ethics Lab...
# Scraping Future of Life Institute...
# Scraping AI Trends...
# Error fetching https://www.aitrends.com/: 503 Server Error: Service Unavailable for url: https://www.aitrends.com/
#                                                 title  \
# 0   Artificial Intelligence Board kicks off work o...
# 1   EU boosts European AI developers with the AI F...
# 2   AI Office received strong interest for partici...
# 3     Using AI to help more college students graduate
# 4   Announcing the NeurIPS 2023 Paper Awards – Neu...
# 5   How to Evaluate Jailbreak Methods: A Case Stud...
# 6   How to Evaluate Jailbreak Methods: A Case Stud...
# 7   Are We Ready for Multi-Image Reasoning? Launch...
# 8   Are We Ready for Multi-Image Reasoning? Launch...
# 9             TinyAgent: Function Calling at the Edge
# 10  Exploring Ways AI Can Address Oral Health Disp...
# 11  AI winter: A cycle of hype, disappointment, an...
# 12  AI winter: A cycle of hype, disappointment, an...
# 13  AI winter: A cycle of hype, disappointment, an...
# 14  OpenAI co-founder’s Safe Superintelligence Inc...
# 15  OpenAI co-founder’s Safe Superintelligence Inc...
# 16  Smartcat secures $43M for its AI-powered trans...
# 17  Smartcat secures $43M for its AI-powered trans...
# 18  Heart disease is the world’s biggest killer — ...
# 19  Heart disease is the world’s biggest killer — ...
# 20  Apple upgrades watchOS with AI-powered feature...
# 21                     News • Nederlandse AI Coalitie
# 22  Center of Expertise for healthcare algorithms ...
# 23                     News • Nederlandse AI Coalitie
# 24                     News • Nederlandse AI Coalitie
# 25                     News • Nederlandse AI Coalitie
#
#                                                   url  \
# 0   https://digital-strategy.ec.europa.eu/en/news/...
# 1   https://digital-strategy.ec.europa.eu/en/news/...
# 2   https://digital-strategy.ec.europa.eu/en/news/...
# 3   https://publicpolicy.google/article/ai-helping...
# 4   https://blog.neurips.cc/2023/12/11/announcing-...
# 5   https://bair.berkeley.edu/blog/2024/08/28/stro...
# 6   https://bair.berkeley.edu/blog/2024/08/28/stro...
# 7   https://bair.berkeley.edu/blog/2024/07/20/visu...
# 8   https://bair.berkeley.edu/blog/2024/07/20/visu...
# 9   https://bair.berkeley.edu/blog/2024/05/29/tiny...
# 10  https://hsdm.harvard.edu/news/exploring-ways-a...
# 11  https://www.artificialintelligence-news.com/ne...
# 12  https://www.artificialintelligence-news.com/ne...
# 13  https://www.artificialintelligence-news.com/ne...
# 14  https://www.artificialintelligence-news.com/ne...
# 15  https://www.artificialintelligence-news.com/ne...
# 16  https://techcrunch.com/2024/09/10/smartcat-sec...
# 17  https://techcrunch.com/2024/09/10/smartcat-sec...
# 18  https://techcrunch.com/2024/09/09/heart-diseas...
# 19  https://techcrunch.com/2024/09/09/heart-diseas...
# 20  https://techcrunch.com/2024/09/09/apple-upgrad...
# 21                 https://nlaic.com/en/news/#content
# 22  https://nlaic.com/en/news/expertise-center-car...
# 23                         https://nlaic.com/en/news/
# 24                         https://nlaic.com/en/news/
# 25  https://nlaic.com/en/news/#elementor-action%3A...
#
#                                               summary  \
# 0   The AI Board is comprised of high-level repres...
# 1   AI Factories will be created around the EU's w...
# 2   The AI Office has received expressions of inte...
# 3   When I started as Undergraduate Dean of John J...
# 4   Announcing the NeurIPS 2023 Paper AwardsBy Ami...
# 5   How to Evaluate Jailbreak Methods: A Case Stud...
# 6   How to Evaluate Jailbreak Methods: A Case Stud...
# 7   To address this gap, this project focuses on t...
# 8   To address this gap, this project focuses on t...
# 9   TinyAgent: Function Calling at the EdgeThe abi...
# 10  As artificial intelligence (AI) is increasingl...
# 11  The term AI winter refers to a period of fundi...
# 12  The term AI winter refers to a period of fundi...
# 13  The term AI winter refers to a period of fundi...
# 14  Just three months after its inception, Safe Su...
# 15  Just three months after its inception, Safe Su...
# 16  AI translations tend to lack the lexical richn...
# 17  AI translations tend to lack the lexical richn...
# 18  While artificial intelligence (AI) promises to...
# 19  While artificial intelligence (AI) promises to...
# 20  Apple’s watchOS is getting a few AI-powered up...
# 21  De technische opslag of toegang is strikt nood...
# 22  The Center of Expertise for healthcare algorit...
# 23  De technische opslag of toegang is strikt nood...
# 24  De technische opslag of toegang is strikt nood...
# 25  De technische opslag of toegang is strikt nood...
#
#                                              keywords  \
# 0   states, implementation, artificial, board, upt...
# 1   factories, computing, startups, providing, ai,...
# 2   strong, interest, generalpurpose, drafting, pr...
# 3   working, way, unable, students, graduate, jay,...
# 4   abilities, emergent, data, models, dec, cst, a...
# 5   evaluate, jailbreak, victim, prompts, methods,...
# 6   evaluate, jailbreak, victim, prompts, methods,...
# 7   question, models, mirage, image, vhs, benchmar...
# 8   question, models, mirage, image, vhs, benchmar...
# 9   data, models, tinyagent, user, calling, plan, ...
# 10  oral, suggest, clinical, exploring, ai, gianno...
# 11  data, machine, recovery, industry, hype, ai, t...
# 12  data, machine, recovery, industry, hype, ai, t...
# 13  data, machine, recovery, industry, hype, ai, t...
# 14  team, secures, superintelligence, companys, sa...
# 15  team, secures, superintelligence, companys, sa...
# 16  43m, translation, services, secures, customers...
# 17  43m, translation, services, secures, customers...
# 18  data, cardiovascular, killer, cardiatec, bigge...
# 19  data, cardiovascular, killer, cardiatec, bigge...
# 20  watchos, translation, features, models, stack,...
# 21  uitdrukkelijk, nederlandse, doel, het, ai, te,...
# 22  data, models, nederlandse, hospitals, patient,...
# 23  uitdrukkelijk, nederlandse, doel, het, ai, te,...
# 24  uitdrukkelijk, nederlandse, doel, het, ai, te,...
# 25  uitdrukkelijk, nederlandse, doel, het, ai, te,...
#
#                 published_date                                       source
# 0   2024-09-10 19:26:43.697871        https://digital-strategy.ec.europa.eu
# 1   2024-09-10 19:26:45.114771        https://digital-strategy.ec.europa.eu
# 2   2024-09-10 19:26:46.775698        https://digital-strategy.ec.europa.eu
# 3   2024-09-10 19:26:49.356771                  https://publicpolicy.google
# 4          2023-12-11 00:00:00                      https://blog.neurips.cc
# 5          2024-08-28 00:00:00                    https://bair.berkeley.edu
# 6          2024-08-28 00:00:00                    https://bair.berkeley.edu
# 7          2024-07-20 00:00:00                    https://bair.berkeley.edu
# 8          2024-07-20 00:00:00                    https://bair.berkeley.edu
# 9          2024-05-29 00:00:00                    https://bair.berkeley.edu
# 10  2024-09-10 19:27:03.633667                     https://hsdm.harvard.edu
# 11   2024-09-09 13:45:35+00:00  https://www.artificialintelligence-news.com
# 12   2024-09-09 13:45:35+00:00  https://www.artificialintelligence-news.com
# 13   2024-09-09 13:45:35+00:00  https://www.artificialintelligence-news.com
# 14   2024-09-09 13:00:51+00:00  https://www.artificialintelligence-news.com
# 15   2024-09-09 13:00:51+00:00  https://www.artificialintelligence-news.com
# 16         2024-09-10 00:00:00                       https://techcrunch.com
# 17         2024-09-10 00:00:00                       https://techcrunch.com
# 18         2024-09-09 00:00:00                       https://techcrunch.com
# 19         2024-09-09 00:00:00                       https://techcrunch.com
# 20         2024-09-09 00:00:00                       https://techcrunch.com
# 21  2024-09-10 19:28:54.160732                            https://nlaic.com
# 22   2023-10-25 00:00:00+02:00                            https://nlaic.com
# 23  2024-09-10 19:29:00.312055                            https://nlaic.com
# 24  2024-09-10 19:29:03.945301                            https://nlaic.com
# 25  2024-09-10 19:29:06.913670                            https://nlaic.com

# %%
from IPython.display import HTML, display
import datetime

def generate_newsletter(df):
    """
    Genereert een HTML-nieuwsbrief van de gescrapete AI-nieuws-artikelen.

    :param df: DataFrame met de gescrapete artikelen
    :return: HTML-string van de nieuwsbrief
    """
    # Sorteer artikelen op publicatiedatum, meest recente eerst
    df = df.sort_values('published_date', ascending=False)

    # Begin de HTML-structuur
    html = f"""
    <html>
    <head>
        <style>
            body {{ font-family: Arial, sans-serif; line-height: 1.6; color: #333; max-width: 800px; margin: 0 auto; padding: 20px; }}
            h1 {{ color: #2c3e50; text-align: center; }}
            h2 {{ color: #3498db; }}
            .article {{ margin-bottom: 30px; border-bottom: 1px solid #eee; padding-bottom: 20px; }}
            .article h3 {{ margin-bottom: 5px; }}
            .article p {{ margin-top: 5px; }}
            .meta {{ font-size: 0.8em; color: #7f8c8d; }}
            a {{ color: #2980b9; text-decoration: none; }}
            a:hover {{ text-decoration: underline; }}
        </style>
    </head>
    <body>
        <h1>AI News Nieuwsbrief</h1>
        <p style="text-align: center;">Gegenereerd op {datetime.datetime.now().strftime('%d-%m-%Y %H:%M')}</p>
    """

    # Voeg elk artikel toe aan de nieuwsbrief
    for _, row in df.iterrows():
        html += f"""
        <div class="article">
            <h2><a href="{row['url']}">{row['title']}</a></h2>
            <p class="meta">Gepubliceerd op: {row['published_date'].strftime('%d-%m-%Y')} | Bron: {row['source']}</p>
            <p>{row['summary']}</p>
            <p><strong>Keywords:</strong> {row['keywords']}</p>
        </div>
        """

    # Sluit de HTML-structuur
    html += """
    </body>
    </html>
    """

    return html

# Functie om de nieuwsbrief weer te geven in de notebook
def display_newsletter(df):
    newsletter_html = generate_newsletter(df)
    display(HTML(newsletter_html))

# Functie om de nieuwsbrief op te slaan als HTML-bestand
def save_newsletter(df, filename='ai_news_newsletter.html'):
    newsletter_html = generate_newsletter(df)
    with open(filename, 'w', encoding='utf-8') as f:
        f.write(newsletter_html)
    print(f"Nieuwsbrief opgeslagen als {filename}")

# Gebruik deze functies na het scrapen van de nieuws-artikelen
# Bijvoorbeeld:
# display_newsletter(news_df)
# save_newsletter(news_df)

# %%
from IPython.display import HTML, display
import datetime
import pytz

def standardize_dates(df):
    """
    Zet alle datums om naar 'naive' UTC datums.
    """
    def to_naive_utc(dt):
        if dt is pd.NaT:
            return dt
        if dt.tzinfo is None:
            # Als er geen tijdzone is, nemen we aan dat het UTC is
            return dt
        return dt.astimezone(pytz.UTC).replace(tzinfo=None)

    df['published_date'] = df['published_date'].apply(to_naive_utc)
    return df

def generate_newsletter(df):
    """
    Genereert een HTML-nieuwsbrief van de gescrapete AI-nieuws-artikelen.

    :param df: DataFrame met de gescrapete artikelen
    :return: HTML-string van de nieuwsbrief
    """
    # Standaardiseer de datums en sorteer
    df = standardize_dates(df)
    df = df.sort_values('published_date', ascending=False)

    # Begin de HTML-structuur
    html = f"""
    <html>
    <head>
        <style>
            body {{ font-family: Arial, sans-serif; line-height: 1.6; color: #333; max-width: 800px; margin: 0 auto; padding: 20px; }}
            h1 {{ color: #2c3e50; text-align: center; }}
            h2 {{ color: #3498db; }}
            .article {{ margin-bottom: 30px; border-bottom: 1px solid #eee; padding-bottom: 20px; }}
            .article h3 {{ margin-bottom: 5px; }}
            .article p {{ margin-top: 5px; }}
            .meta {{ font-size: 0.8em; color: #7f8c8d; }}
            a {{ color: #2980b9; text-decoration: none; }}
            a:hover {{ text-decoration: underline; }}
        </style>
    </head>
    <body>
        <h1>AI News Nieuwsbrief</h1>
        <p style="text-align: center;">Gegenereerd op {datetime.datetime.now().strftime('%d-%m-%Y %H:%M')} UTC</p>
    """

    # Voeg elk artikel toe aan de nieuwsbrief
    for _, row in df.iterrows():
        published_date = row['published_date'].strftime('%d-%m-%Y') if pd.notna(row['published_date']) else 'Onbekende datum'
        html += f"""
        <div class="article">
            <h2><a href="{row['url']}">{row['title']}</a></h2>
            <p class="meta">Gepubliceerd op: {published_date} | Bron: {row['source']}</p>
            <p>{row['summary']}</p>
            <p><strong>Keywords:</strong> {row['keywords']}</p>
        </div>
        """

    # Sluit de HTML-structuur
    html += """
    </body>
    </html>
    """

    return html

# Functie om de nieuwsbrief weer te geven in de notebook
def display_newsletter(df):
    newsletter_html = generate_newsletter(df)
    display(HTML(newsletter_html))

# Functie om de nieuwsbrief op te slaan als HTML-bestand
def save_newsletter(df, filename='ai_news_newsletter.html'):
    newsletter_html = generate_newsletter(df)
    with open(filename, 'w', encoding='utf-8') as f:
        f.write(newsletter_html)
    print(f"Nieuwsbrief opgeslagen als {filename}")

# Gebruik deze functies na het scrapen van de nieuws-artikelen
# Bijvoorbeeld:
# display_newsletter(news_df)
# save_newsletter(news_df)

# %%
# !pip install pytz
# Out:
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (2024.1)

# %%
display_newsletter(news_df)
# Out:
#     <html>
#     <head>
#         <style>
#             body { font-family: Arial, sans-serif; line-height: 1.6; color: #333; max-width: 800px; margin: 0 auto; padding: 20px; }
#             h1 { color: #2c3e50; text-align: center; }
#             h2 { color: #3498db; }
#             .article { margin-bottom: 30px; border-bottom: 1px solid #eee; padding-bottom: 20px; }
#             .article h3 { margin-bottom: 5px; }
#             .article p { margin-top: 5px; }
#             .meta { font-size: 0.8em; color: #7f8c8d; }
#             a { color: #2980b9; text-decoration: none; }
#             a:hover { text-decoration: underline; }
#         </style>
#     </head>
#     <body>
#         <h1>AI News Nieuwsbrief</h1>
#         <p style="text-align: center;">Gegenereerd op 10-09-2024 19:33 UTC</p>
#
#         <div class="article">
#             <h2><a href="https://nlaic.com/en/news/#elementor-action%3Aaction%3Dpopup%3Aopen%26settings%3DeyJpZCI6MTAzNTg5LCJ0b2dnbGUiOnRydWV9">News • Nederlandse AI Coalitie</a></h2>
#             <p class="meta">Gepubliceerd op: 10-09-2024 | Bron: https://nlaic.com</p>
#             <p>De technische opslag of toegang is strikt noodzakelijk voor het legitieme doel om het gebruik van een specifieke dienst mogelijk te maken die uitdrukkelijk door de abonnee of gebruiker is gevraagd, of voor het enige doel om de overdracht van communicatie via een elektronisch communicatienetwerk uit te voeren.
# De technische opslag of toegang is strikt noodzakelijk voor het legitieme doel om het gebruik van een specifieke dienst mogelijk te maken die uitdrukkelijk door de abonnee of gebruiker is gevraagd, of voor het enige doel om de overdracht van communicatie via een elektronisch communicatienetwerk uit te voeren.
# Preferences Preferences</p>
#             <p><strong>Keywords:</strong> uitdrukkelijk, nederlandse, doel, het, ai, te, uit, voor, coalitie, om, toegang, een, van</p>
#         </div>
#
#         <div class="article">
#             <h2><a href="https://nlaic.com/en/news/">News • Nederlandse AI Coalitie</a></h2>
#             <p class="meta">Gepubliceerd op: 10-09-2024 | Bron: https://nlaic.com</p>
#             <p>De technische opslag of toegang is strikt noodzakelijk voor het legitieme doel om het gebruik van een specifieke dienst mogelijk te maken die uitdrukkelijk door de abonnee of gebruiker is gevraagd, of voor het enige doel om de overdracht van communicatie via een elektronisch communicatienetwerk uit te voeren.
# De technische opslag of toegang is strikt noodzakelijk voor het legitieme doel om het gebruik van een specifieke dienst mogelijk te maken die uitdrukkelijk door de abonnee of gebruiker is gevraagd, of voor het enige doel om de overdracht van communicatie via een elektronisch communicatienetwerk uit te voeren.
# Preferences Preferences</p>
#             <p><strong>Keywords:</strong> uitdrukkelijk, nederlandse, doel, het, ai, te, uit, voor, coalitie, om, toegang, een, van</p>
#         </div>
#
#         <div class="article">
#             <h2><a href="https://nlaic.com/en/news/">News • Nederlandse AI Coalitie</a></h2>
#             <p class="meta">Gepubliceerd op: 10-09-2024 | Bron: https://nlaic.com</p>
#             <p>De technische opslag of toegang is strikt noodzakelijk voor het legitieme doel om het gebruik van een specifieke dienst mogelijk te maken die uitdrukkelijk door de abonnee of gebruiker is gevraagd, of voor het enige doel om de overdracht van communicatie via een elektronisch communicatienetwerk uit te voeren.
# De technische opslag of toegang is strikt noodzakelijk voor het legitieme doel om het gebruik van een specifieke dienst mogelijk te maken die uitdrukkelijk door de abonnee of gebruiker is gevraagd, of voor het enige doel om de overdracht van communicatie via een elektronisch communicatienetwerk uit te voeren.
# Preferences Preferences</p>
#             <p><strong>Keywords:</strong> uitdrukkelijk, nederlandse, doel, het, ai, te, uit, voor, coalitie, om, toegang, een, van</p>
#         </div>
#
#         <div class="article">
#             <h2><a href="https://nlaic.com/en/news/#content">News • Nederlandse AI Coalitie</a></h2>
#             <p class="meta">Gepubliceerd op: 10-09-2024 | Bron: https://nlaic.com</p>
#             <p>De technische opslag of toegang is strikt noodzakelijk voor het legitieme doel om het gebruik van een specifieke dienst mogelijk te maken die uitdrukkelijk door de abonnee of gebruiker is gevraagd, of voor het enige doel om de overdracht van communicatie via een elektronisch communicatienetwerk uit te voeren.
# De technische opslag of toegang is strikt noodzakelijk voor het legitieme doel om het gebruik van een specifieke dienst mogelijk te maken die uitdrukkelijk door de abonnee of gebruiker is gevraagd, of voor het enige doel om de overdracht van communicatie via een elektronisch communicatienetwerk uit te voeren.
# Preferences Preferences</p>
#             <p><strong>Keywords:</strong> uitdrukkelijk, nederlandse, doel, het, ai, te, uit, voor, coalitie, om, toegang, een, van</p>
#         </div>
#
#         <div class="article">
#             <h2><a href="https://hsdm.harvard.edu/news/exploring-ways-ai-can-address-oral-health-disparities">Exploring Ways AI Can Address Oral Health Disparities</a></h2>
#             <p class="meta">Gepubliceerd op: 10-09-2024 | Bron: https://hsdm.harvard.edu</p>
#             <p>As artificial intelligence (AI) is increasingly being used in many facets of health care including dentistry, the authors of a recently-published opinion piece in JAMA Health Forum discuss ways AI can help level the playing field to achieve greater oral health equity.
# Harvard School of Dental Medicine (HSDM) faculty members Hawazin Elani, assistant professor in Oral Health Policy and Epidemiology, and William Giannobile, dean and A. Lee Loomis, Jr.
# Professor of Oral Medicine, Infection and Immunity, point to AI’s potential to reduce health disparities in three ways starting with the ability to enable earlier diagnoses and intervention.
# While these areas are promising for the application of AI, the authors also call for caution when evaluating the AI tools rapidly coming on the market.
# “This underscores the role academia can play in bringing together different stakeholders and fostering a shared responsibility in the development of AI to improve oral health for all.”</p>
#             <p><strong>Keywords:</strong> oral, suggest, clinical, exploring, ai, giannobile, health, elani, authors, ways, dental, address, care, disparities</p>
#         </div>
#
#         <div class="article">
#             <h2><a href="https://publicpolicy.google/article/ai-helping-college-students-graduate/">Using AI to help more college students graduate</a></h2>
#             <p class="meta">Gepubliceerd op: 10-09-2024 | Bron: https://publicpolicy.google</p>
#             <p>When I started as Undergraduate Dean of John Jay College, our senior graduation rate was 54%.
# I knew we could do better for our students.
# John Jay serves many first generation Americans and nontraditional students.
# Many are working while studying, some are parents and the main source of income for their families, and have taken different paths to their degrees.
# We understand that they are dealing with competing priorities in a way that the traditional undergraduate student is not, which often means that many students are unable to complete their degrees on time.</p>
#             <p><strong>Keywords:</strong> working, way, unable, students, graduate, jay, traditional, ai, help, undergraduate, taken, using, degrees, college, understand</p>
#         </div>
#
#         <div class="article">
#             <h2><a href="https://digital-strategy.ec.europa.eu/en/news/ai-office-received-strong-interest-participation-drafting-first-general-purpose-ai-code-practice">AI Office received strong interest for participation in drafting the first General-Purpose AI Code of Practice</a></h2>
#             <p class="meta">Gepubliceerd op: 10-09-2024 | Bron: https://digital-strategy.ec.europa.eu</p>

# %%
save_newsletter(news_df)
# Out:
# Nieuwsbrief opgeslagen als ai_news_newsletter.html
